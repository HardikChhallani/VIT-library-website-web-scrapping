# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
from tqdm.notebook import tqdm_notebook
from concurrent.futures import ThreadPoolExecutor

# %%
session = requests.Session()

payload = {
    'userid': '22BCE2454',
    'password': '#Un3599known'
}

url = "http://webopac.vit.ac.in/"
s = session.post(url, data=payload)
s
# Out:
# <Response [200]>

# %%
final_df = pd.DataFrame()

# %%
def scrape_page(i):
    webpage = session.get(f'http://webopac.vit.ac.in/cgi-bin/koha/opac-search.pl?&limit=yr%2Cst-numeric%3D1984-&offset={i}&sort_by=relevance').text
    soup = BeautifulSoup(webpage, 'lxml')
    content = soup.find_all('td', class_='bibliocol')
    
    title = []
    author = []
    barcode = []
    location = []
    material_type = []
    format_form = []
    literary_form = []
    publisher = []
    available = []
    img_link = []

    for j in content:
        try:
            title.append(j.find('a', class_='title').text.strip())
        except:
            title.append(np.nan)
        try:
            author.append(j.find('span', class_='author').text.strip())
        except:
            author.append(np.nan)
        try:
            barcode.append(j.find('span', class_='results_summary Barcode').contents[-1].strip())
        except:
            barcode.append(np.nan)
        try:
            location.append(j.find('span', class_='results_summary Location').contents[-1].strip())
        except:
            location.append(np.nan)
        try:
            material_type.append(j.find('span', class_='results_material_type').contents[-1].strip())
        except:
            material_type.append(np.nan)
        try:
            format_form.append(j.find('span', class_='results_format').contents[-1].strip())
        except:
            format_form.append(np.nan)
        try:
            literary_form.append(j.find('span', class_='results_contents_literary').contents[-1].strip())
        except:
            literary_form.append(np.nan)
        try:
            publisher.append(j.find('span', class_='results_summary publisher').contents[-1].strip())
        except:
            publisher.append(np.nan)
        try:
            available.append(j.find('span', class_='available').text.strip())
        except:
            available.append(np.nan)
        try:
            img_link.append(j.find('img').get('src'))
        except:
            img_link.append(np.nan)

    df = pd.DataFrame({
        'Title': title,
        'Author': author,
        "Barcode Number": barcode,
        "Location In Library": location,
        "Material type": material_type,
        "Format": format_form,
        "Literary form": literary_form,
        "Publisher": publisher,
        "Availability": available,
        "Image": img_link
    })

    return df

# %%
# Define the range of offsets to scrape
offsets = range(0, 92940, 20)

# Use ThreadPoolExecutor to scrape pages in parallel
with ThreadPoolExecutor(max_workers=8) as executor:
    dataframes = list(tqdm_notebook(executor.map(scrape_page, offsets), total=len(offsets)))
# Out:
#   0%|          | 0/4647 [00:00<?, ?it/s]

# %%
# Concatenate the dataframes
final_df = pd.concat(dataframes, ignore_index=True)
final_df
# Out:
#                                              Title  \
# 0                                  changing places
# 1                chapel noir: an irene adler novel
# 2                                       coast road
# 3                                   collision bend
# 4                                           compat
# ...                                            ...
# 90199         FINANCIAL VALUATION AND ECONOMETRICS
# 90200                 INTRODUCTION TO MICROFINANCE
# 90201  R IN FINANCE AND ECONOMICS A BEGINNER GUIDE
# 90202          FOUNDATIONS OF QUANTUM FIELD THEORY
# 90203             ADVANCED ARTIFICIAL INTELLIGENCE
#
#                                         Author Barcode Number  \
# 0                                 judy kramer.        116002.
# 1                       carole nelson douglas.        116004.
# 2                            barbara delinsky.        116023.
# 3                                 roberts les.        116033.
# 4                              coonts stephen.        116037.
# ...                                        ...            ...
# 90199                           LIM KIAN GUAN.        245666.
# 90200                          WATKINS TODD A.        245665.
# 90201  ABHAY KUMAR SINGH ; DAVID EDMUND ALLEN.        245664.
# 90202                           ROTHE KLAUS D.        245663.
# 90203                            SHI ZHONGZHI.        245662.
#
#       Location In Library Material type Format Literary form  \
# 0            IIIF-R1-C4-C          Text  print   Not fiction
# 1            IIF-R70-C1-E          Text  print   Not fiction
# 2            IIF-R70-C4-B          Text  print   Not fiction
# 3            IIF-R72-C3-B          Text  print   Not fiction
# 4            IIF-R70-C2-F          Text  print   Not fiction
# ...                   ...           ...    ...           ...
# 90199                              Text  print   Not fiction
# 90200                              Text  print   Not fiction
# 90201                              Text  print   Not fiction
# 90202                              Text  print   Not fiction
# 90203                              Text  print   Not fiction
#
#                                                Publisher  \
# 0                  new york  ;  riverhead books ;   2000
# 1                     new york  ;  a forge book ;   2001
# 2                        simon ANDamp; schuster ;   1998
# 3          new york  ;  st. martin`s press inc. ;   1996
# 4      new york  ;  a tom doherty associates book ;  ...
# ...                                                  ...
# 90199              LONDON  ;  WORLD SCIENTIFIC  ;   2020
# 90200              LONDON  ;  WORLD SCIENTIFIC  ;   2022
# 90201              LONDON  ;  WORLD SCIENTIFIC  ;   2021
# 90202              LONDON  ;  WORLD SCIENTIFIC  ;   2021
# 90203              LONDON  ;  WORLD SCIENTIFIC  ;   2022
#
#                                             Availability  \
# 0      Items available for loan: Vellore Institute of...
# 1      Items available for loan: Vellore Institute of...
# 2      Items available for loan: Vellore Institute of...
# 3      Items available for loan: Vellore Institute of...
# 4      Items available for loan: Vellore Institute of...
# ...                                                  ...
# 90199  Items available for reference: Vellore Institu...
# 90200  Items available for reference: Vellore Institu...
# 90201  Items available for reference: Vellore Institu...
# 90202  Items available for reference: Vellore Institu...
# 90203  Items available for reference: Vellore Institu...
#
#                                                    Image
# 0      https://images-na.ssl-images-amazon.com/images...
# 1      https://images-na.ssl-images-amazon.com/images...
# 2      https://images-na.ssl-images-amazon.com/images...
# 3      https://images-na.ssl-images-amazon.com/images...
# 4      https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 90199  https://images-na.ssl-images-amazon.com/images...
# 90200  https://images-na.ssl-images-amazon.com/images...
# 90201                    /opac-tmpl/lib/famfamfam/BK.png
# 90202  https://images-na.ssl-images-amazon.com/images...
# 90203  https://images-na.ssl-images-amazon.com/images...
#
# [90204 rows x 10 columns]

# %%
final_df.duplicated().sample(10)
# Out:
# 21695    False
# 30833    False
# 31990    False
# 67838    False
# 51087     True
# 53805    False
# 52734    False
# 69014    False
# 44246     True
# 59469     True
# dtype: bool

# %%
final_df.drop(final_df.duplicated(),axis='columns',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 final_df.drop(final_df.duplicated(),axis='columns',inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: '[False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False ...

# %%
final_df.to_csv('NewKoha.csv')
