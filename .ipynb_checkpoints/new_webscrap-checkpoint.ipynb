# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
from tqdm.notebook import tqdm_notebook
import time

# %%
session = requests.Session()

payload = {
    'userid':'22BCE2454',
    'password':'#Un3599known'
}

url = "http://webopac.vit.ac.in/"
s = session.post(url,data=payload)
s
# Out:
# <Response [200]>

# %%
#final_df = pd.DataFrame()

# %%
for i in tqdm_notebook(range(0,30000,20)):
    webpage = session.get(f'http://webopac.vit.ac.in/cgi-bin/koha/opac-search.pl?&limit=yr%2Cst-numeric%3D1984-&offset={i}&sort_by=relevance').text
    soup = BeautifulSoup(webpage,'lxml')
    content = soup.find_all('td',class_='bibliocol')
    title = []
    author= []
    barcode = []
    location = []
    material_type = []
    format_form = []
    literary_form = []
    publisher = []
    available = []
    img_link = []
    for j in content:
        try:
            title.append(j.find('a',class_='title').text.strip())
        except:
            title.append(np.nan)
        try:
            author.append(j.find('span',class_='author').text.strip())
        except:
            author.append(np.nan)
        try:
            barcode.append(j.find('span',class_='results_summary Barcode').contents[-1].strip())
        except:
            barcode.append(np.nan)
        try:
            location.append(j.find('span',class_='results_summary Location').contents[-1].strip())
        except:
            location.append(np.nan)
        try:
            material_type.append(j.find('span',class_='results_material_type').contents[-1].strip())
        except:
            material_type.append(np.nan)
        try:
            format_form.append(j.find('span',class_='results_format').contents[-1].strip())
        except:
            format_form.append(np.nan)
        try:
            literary_form.append(j.find('span',class_='results_contents_literary').contents[-1].strip())
        except:
            literary_form.append(np.nan)
        try:
            publisher.append(j.find('span',class_='results_summary publisher').contents[-1].strip())
        except:
            publisher.append(np.nan)
        try:
            available.append(j.find('span',class_='available').text.strip())
        except:
            available.append(np.nan)
        try:
            img_link.append(j.find('img').get('src'))
        except:
            img_link.append(np.nan)
    
    df = pd.DataFrame({
    'Title':title,
    'Author':author,
    "Barcode Number":barcode,
    "Location In Library":location,
    "Material type":material_type,
    "Format":format_form,
    "Literary form":literary_form,
    "Publisher":publisher,
    "Availability":available,
    "Image":img_link
    })
    final_df = pd.concat([final_df,df],ignore_index = True)
    time.sleep(0.1)
    print(final_df['Title'].tail(1))
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]
# 16    death at glamis castle
# Name: Title, dtype: object
# 34    elizabeth and after
# Name: Title, dtype: object
# 51    flesh and blood
# Name: Title, dtype: object
# 65    greetings from the lincoln
# Name: Title, dtype: object
# 80    high tide
# Name: Title, dtype: object
# 93    in sunlight in a beautiful garden
# Name: Title, dtype: object
# 107    leading with my heart
# Name: Title, dtype: object
# 124    memories can be murder: the fifth charlie pank...
# Name: Title, dtype: object
# 136    murder at bertrams bower
# Name: Title, dtype: object
# 148    on the rez
# Name: Title, dtype: object
# 165    prey to all
# Name: Title, dtype: object
# 179    roses are red
# Name: Title, dtype: object
# 194    singing in the comback choir
# Name: Title, dtype: object
# 210    sticks and scones
# Name: Title, dtype: object
# 223    the aftermath: a novel of survival
# Name: Title, dtype: object
# 238    the derils workshop
# Name: Title, dtype: object
# 250    the immaculate deception
# Name: Title, dtype: object
# 269    the night vistitor
# Name: Title, dtype: object
# 286    the song of the tide
# Name: Title, dtype: object
# 299    the wind done gone
# Name: Title, dtype: object
# 316    twanged
# Name: Title, dtype: object
# 332    when tommorrow comes
# Name: Title, dtype: object
# 340    statistical methods
# Name: Title, dtype: object
# 357    sentamizh therpagarkal
# Name: Title, dtype: object
# 377    modern digital and analog communication systems
# Name: Title, dtype: object
# 390    eager to please
# Name: Title, dtype: object
# 406    love stories of world war ii
# Name: Title, dtype: object
# 422    the courtship gift: a novel
# Name: Title, dtype: object
# 435    the wild blue: the men and boys who flew the b...
# Name: Title, dtype: object
# 450    time in the living world
# Name: Title, dtype: object
# 468    bharathi thaasan paadalkal
# Name: Title, dtype: object
# 488    geometric dimensioning and tolerancing: workbo...
# Name: Title, dtype: object
# 508    applying moleuclar and materials modeling
# Name: Title, dtype: object
# 528    classical electrodynamics
# Name: Title, dtype: object
# 547    principles of unit operations
# Name: Title, dtype: object
# 565    network security: a hackers perspective
# Name: Title, dtype: object
# 578    a textbook of material science
# Name: Title, dtype: object
# 589    finite element analysis in engineering design
# Name: Title, dtype: object
# 600    optical fibres and fibre optic communication s...
# Name: Title, dtype: object
# 616    a textbook of digital computer electroncis
# Name: Title, dtype: object
# 632    theory of structures
# Name: Title, dtype: object
# 649    harpers illustrated biochemistry
# Name: Title, dtype: object
# 664    principles of industrial instrumentation
# Name: Title, dtype: object
# 677    basic and applied thermodynamics
# Name: Title, dtype: object
# 691    digital communications
# Name: Title, dtype: object
# 707    stereochemistry conformation and mechanism
# Name: Title, dtype: object
# 720    an introduction to formal languages and automata
# Name: Title, dtype: object
# 731    Programming microsoft visual C++ (With CD): CD...
# Name: Title, dtype: object
# 750    fundamentals of computers
# Name: Title, dtype: object
# 764    computer architechture: a quantitative approach
# Name: Title, dtype: object
# 779    a textbook of fluid mechanics and hydraulic ma...
# Name: Title, dtype: object
# 791    international business environment
# Name: Title, dtype: object
# 802    microprocessor (8085) and it applications
# Name: Title, dtype: object
# 817    8051 Microcontroller (With CD): CD6933
# Name: Title, dtype: object
# 833    programming with java 3e primer
# Name: Title, dtype: object
# 848    Microprocessor architecture programming and ap...
# Name: Title, dtype: object
# 865    data structures: a psevdocode approach with c
# Name: Title, dtype: object
# 880    manufacturing engineering and technology
# Name: Title, dtype: object
# 899    harpers illustrated biochemistry
# Name: Title, dtype: object
# 914    solid state physics
# Name: Title, dtype: object
# 926    software testing in the real world improving t...
# Name: Title, dtype: object
# 935    software engineering
# Name: Title, dtype: object
# 948    thermal engineering
# Name: Title, dtype: object
# 964    advanced chemistry: physical and industrial
# Name: Title, dtype: object
# 979    heat transfer
# Name: Title, dtype: object
# 997    the 8051 microcontroller and embedded systems ...
# Name: Title, dtype: object
# 1014    marketing management
# Name: Title, dtype: object
# 1031    let us c
# Name: Title, dtype: object
# 1049    verilog hdl synthesis: a practical primer
# Name: Title, dtype: object
# 1065    network theory
# Name: Title, dtype: object
# 1080    "principles of environmental studies (ecology,...
# Name: Title, dtype: object
# 1097    puthaka kalai
# Name: Title, dtype: object
# 1117    tamiz sudar manigal
# Name: Title, dtype: object
# 1135    saiva samaya then
# Name: Title, dtype: object
# 1154    tryst with global competition: stretegic respo...
# Name: Title, dtype: object
# 1171    readings in managerial economics accounting an...
# Name: Title, dtype: object
# 1190    fundamentals of biotechnology forensic science...
# Name: Title, dtype: object
# 1210    essentials of biotechnology
# Name: Title, dtype: object
# 1230    modern concepts in biotechnology
# Name: Title, dtype: object
# 1250    new frontiers in biotechnology
# Name: Title, dtype: object
# 1265    engineering physics i: with practical first se...
# Name: Title, dtype: object
# 1278    solid state physics
# Name: Title, dtype: object
# 1289    engineering mathematics: first year common for...
# Name: Title, dtype: object
# 1295    "probability, statistics and random processes"
# Name: Title, dtype: object
# 1308    probability and queueing theory
# Name: Title, dtype: object
# 1319    electronic devices
# Name: Title, dtype: object
# 1335    signals and systems
# Name: Title, dtype: object
# 1349    communication theory: for ece students
# Name: Title, dtype: object
# 1359    circuit theory (electric circuit analysis)
# Name: Title, dtype: object
# 1379    visual programming
# Name: Title, dtype: object
# 1387    an introduction to object oriented programming...
# Name: Title, dtype: object
# 1404    total quality management
# Name: Title, dtype: object
# 1414    design of transmission systems
# Name: Title, dtype: object
# 1429    operations research
# Name: Title, dtype: object
# 1445    manufacturing technology -ii
# Name: Title, dtype: object
# 1456    engineering mechanics
# Name: Title, dtype: object
# 1471    manufacturing technology -i
# Name: Title, dtype: object
# 1485    principles of environmental science and engine...
# Name: Title, dtype: object
# 1505    understanding probability and statistics: a bo...
# Name: Title, dtype: object
# 1523    structure and interpretation of computer programs
# Name: Title, dtype: object
# 1541    engineering analysis in applied mechanics
# Name: Title, dtype: object
# 1556    solutions manual for an introduction to thermo...
# Name: Title, dtype: object
# 1574    structural design and drawing reinforced concr...
# Name: Title, dtype: object
# 1593    dimensions of environmental and ecological eco...
# Name: Title, dtype: object
# 1613    sucessful branding
# Name: Title, dtype: object
# 1631    network theory
# Name: Title, dtype: object
# 1647    applied chemistry
# Name: Title, dtype: object
# 1657    human resources development: theory and practice
# Name: Title, dtype: object
# 1676    principles of biochemistry
# Name: Title, dtype: object
# 1695    stereochemistry at a glance
# Name: Title, dtype: object
# 1715    history of the arabs
# Name: Title, dtype: object
# 1734    ram ki shakti puja aur nirala
# Name: Title, dtype: object
# 1754    patrakarita evam press kanoon
# Name: Title, dtype: object
# 1774    sumo (shut up move on) the straight talking gu...
# Name: Title, dtype: object
# 1789    unofficial guide to ethical hacking
# Name: Title, dtype: object
# 1798    concepts of physics part 1
# Name: Title, dtype: object
# 1815    sliding friction: physical principles and appl...
# Name: Title, dtype: object
# 1829    nuclear physics
# Name: Title, dtype: object
# 1847    theory and problems of probability
# Name: Title, dtype: object
# 1865    "theory and problems of probability, random va...
# Name: Title, dtype: object
# 1882    recent progress in medicinal plants: search fo...
# Name: Title, dtype: object
# 1898    process equipment design
# Name: Title, dtype: object
# 1914    network theory: a simplified approach
# Name: Title, dtype: object
# 1928    managing entrepreneurship development
# Name: Title, dtype: object
# 1947    research methodology
# Name: Title, dtype: object
# 1966    organic reaction mechanisms
# Name: Title, dtype: object
# 1986    systematic lab experiments in organic chemistry
# Name: Title, dtype: object
# 2001    communication systems engineering
# Name: Title, dtype: object
# 2021    Electromagnetics for engineers (With CD): CD7193
# Name: Title, dtype: object
# 2038    Embedded microcomputer systems: Real time inte...
# Name: Title, dtype: object
# 2053    fundamentals of electric circuits
# Name: Title, dtype: object
# 2070    microprocessors based design
# Name: Title, dtype: object
# 2087    Operations research: An introduction (With CD)...
# Name: Title, dtype: object
# 2103    signals systems and transforms
# Name: Title, dtype: object
# 2116    micro electronics: analysis and design
# Name: Title, dtype: object
# 2136    Environmental science (With CD): CD7228
# Name: Title, dtype: object
# 2156    practical chemistry
# Name: Title, dtype: object
# 2172    digital systems: principles and applications
# Name: Title, dtype: object
# 2189    manufacturing engineering and technology
# Name: Title, dtype: object
# 2205    manufacturing engineering and technology
# Name: Title, dtype: object
# 2225    "the glass palace: the magnificent, poignant, ...
# Name: Title, dtype: object
# 2240    vogles textbook of quantitative chemical analysis
# Name: Title, dtype: object
# 2258    the wealth of india: raw materials
# Name: Title, dtype: object
# 2277    comprehensive experimental chemistry
# Name: Title, dtype: object
# 2295    physics of semiconductor devices
# Name: Title, dtype: object
# 2314    interest tables for engineering economics
# Name: Title, dtype: object
# 2330    Embedded system architecture: A comprehensive ...
# Name: Title, dtype: object
# 2347    intoduction to matlab 6
# Name: Title, dtype: object
# 2363    principles of polymerization
# Name: Title, dtype: object
# 2379    Thermal sciences: An introduction to thermodyn...
# Name: Title, dtype: object
# 2392    research methodology: methods and techniques
# Name: Title, dtype: object
# 2407    the c programming langauge
# Name: Title, dtype: object
# 2423    an introduction to formal languages and automata
# Name: Title, dtype: object
# 2441    marketing: an introductory text
# Name: Title, dtype: object
# 2461    mathematical methods of airfoil design: invers...
# Name: Title, dtype: object
# 2481    macroeconomic policy growth and poverty reduction
# Name: Title, dtype: object
# 2501    essential quantitative methods: a guide for bu...
# Name: Title, dtype: object
# 2517    Basics of CMOS all design (With CD): CD7345
# Name: Title, dtype: object
# 2535    voice and data communication handbook
# Name: Title, dtype: object
# 2552    pressure vessel design: the direct route
# Name: Title, dtype: object
# 2571    parallel computer architecture: a hardware / s...
# Name: Title, dtype: object
# 2585    communicating at work: principles and practice...
# Name: Title, dtype: object
# 2598    matlab and simulink: introduction to applictions
# Name: Title, dtype: object
# 2616    mathematical and statistics for management
# Name: Title, dtype: object
# 2633    digital design: principles and practices
# Name: Title, dtype: object
# 2649    engineering thermodynamics: work and heat tran...
# Name: Title, dtype: object
# 2663    Introduction to finite elements in engineering...
# Name: Title, dtype: object
# 2680    the 8051 microcontroller and embedded systems:...
# Name: Title, dtype: object
# 2698    "business market management: understanding, cr...
# Name: Title, dtype: object
# 2717    cmos vlsi design: a circuit and systems perspe...
# Name: Title, dtype: object
# 2733    instrumentation measurement and analysis
# Name: Title, dtype: object
# 2749    managing global software projects
# Name: Title, dtype: object
# 2768    electromagnetics
# Name: Title, dtype: object
# 2786    measurement systems: application and design
# Name: Title, dtype: object
# 2804    international human resource management text a...
# Name: Title, dtype: object
# 2821    electronic communication systems
# Name: Title, dtype: object
# 2839    digital and analog communication systems
# Name: Title, dtype: object
# 2857    strategic market management
# Name: Title, dtype: object
# 2875    electric motor drives: modeling analysis and c...
# Name: Title, dtype: object
# 2892    microprocessor based design: a comprehensive g...
# Name: Title, dtype: object
# 2907    "nanosystems: molecular machinery manufacturin...
# Name: Title, dtype: object
# 2926    financial administration
# Name: Title, dtype: object
# 2946    operations research: with economic and insustr...
# Name: Title, dtype: object
# 2963    business mathematics
# Name: Title, dtype: object
# 2979    optical networks: a practical perspective
# Name: Title, dtype: object
# 2988    programming with java: a primer
# Name: Title, dtype: object
# 3004    microprocessors and interfacing: programming a...
# Name: Title, dtype: object
# 3022    digital fundamentals
# Name: Title, dtype: object
# 3041    programming in c
# Name: Title, dtype: object
# 3056    Verilog HDL: A guide to digital design and syn...
# Name: Title, dtype: object
# 3075    an introduction to thermodynamics
# Name: Title, dtype: object
# 3092    measurement systems: application and design
# Name: Title, dtype: object
# 3110    research methodology: methods and techniques
# Name: Title, dtype: object
# 3125    management information systems
# Name: Title, dtype: object
# 3139    the complete reference java 2
# Name: Title, dtype: object
# 3157    data communications and networking
# Name: Title, dtype: object
# 3174    computer system architecture
# Name: Title, dtype: object
# 3192    gate 2008: chemical engineering
# Name: Title, dtype: object
# 3203    advanced physics for engineers
# Name: Title, dtype: object
# 3217    principles of industrial instrumentation
# Name: Title, dtype: object
# 3236    chemical process control: an introduction to t...
# Name: Title, dtype: object
# 3252    introduction to chemical engineering
# Name: Title, dtype: object
# 3268    let us c++
# Name: Title, dtype: object
# 3286    engineering mathematics: for first year
# Name: Title, dtype: object
# 3302    general knowledge manual 2007
# Name: Title, dtype: object
# 3321    operations research
# Name: Title, dtype: object
# 3339    objective general knowledge
# Name: Title, dtype: object
# 3355    engineering chemistry
# Name: Title, dtype: object
# 3372    engineering physics: first year
# Name: Title, dtype: object
# 3389    engineering physics i
# Name: Title, dtype: object
# 3405    engineering physics
# Name: Title, dtype: object
# 3421    solid state physics
# Name: Title, dtype: object
# 3435    material science
# Name: Title, dtype: object
# 3450    automobile engineering
# Name: Title, dtype: object
# 3463    applied chemistry
# Name: Title, dtype: object
# 3477    engineering mathematics
# Name: Title, dtype: object
# 3488    design of transmission systems
# Name: Title, dtype: object
# 3495    probability statistics and random process
# Name: Title, dtype: object
# 3509    probability and queueing theory
# Name: Title, dtype: object
# 3523    optical communication
# Name: Title, dtype: object
# 3540    measurements and instrumentation
# Name: Title, dtype: object
# 3555    operations research
# Name: Title, dtype: object
# 3563    electronics and microprocessors
# Name: Title, dtype: object
# 3575    microprocessor and its applications
# Name: Title, dtype: object
# 3590    analog and digital communication
# Name: Title, dtype: object
# 3601    power electronics
# Name: Title, dtype: object
# 3617    analytical instruments
# Name: Title, dtype: object
# 3632    industrial instrumentation - i
# Name: Title, dtype: object
# 3646    visual programming
# Name: Title, dtype: object
# 3661    digital computer fundamentals
# Name: Title, dtype: object
# 3673    computer networks
# Name: Title, dtype: object
# 3676    computer networks
# Name: Title, dtype: object
# 3692    computer architecture and organization
# Name: Title, dtype: object
# 3706    total quality management
# Name: Title, dtype: object
# 3721    design of machine elements
# Name: Title, dtype: object
# 3740    manufacturing technology - ii
# Name: Title, dtype: object
# 3754    thermal engineering
# Name: Title, dtype: object
# 3768    engineering mechanics
# Name: Title, dtype: object
# 3782    engineering mechanics
# Name: Title, dtype: object
# 3800    solid and fluid mechanics
# Name: Title, dtype: object
# 3809    digital logic and computer design
# Name: Title, dtype: object
# 3824    textbook of environmental studies: for undergr...
# Name: Title, dtype: object
# 3833    programming with ansi and turbo c
# Name: Title, dtype: object
# 3851    mastering c++
# Name: Title, dtype: object
# 3867    advanced physics for engineers
# Name: Title, dtype: object
# 3886    digital design: principles and practices
# Name: Title, dtype: object
# 3898    the intel microprocessors: architecture progra...
# Name: Title, dtype: object
# 3912    Digital design (With CD): CD7932
# Name: Title, dtype: object
# 3927    the pearson concise general knowledge manual 2008
# Name: Title, dtype: object
# 3938    life on campus
# Name: Title, dtype: object
# 3954    engineering drawing
# Name: Title, dtype: object
# 3965    higher engineering mathematics
# Name: Title, dtype: object
# 3979    60 landmark years
# Name: Title, dtype: object
# 3994    microprocessors and digital systems
# Name: Title, dtype: object
# 4010    hindi anusandhan
# Name: Title, dtype: object
# 4028    chemical engineering design
# Name: Title, dtype: object
# 4046    a textbook of chemical engineering thermodynamics
# Name: Title, dtype: object
# 4058    Callisters materials science and engineering (...
# Name: Title, dtype: object
# 4075    the insider
# Name: Title, dtype: object
# 4092    local search in combinatorial optimization
# Name: Title, dtype: object
# 4112    principles of macroeconomics
# Name: Title, dtype: object
# 4130    Electrical engineering: Principles and applica...
# Name: Title, dtype: object
# 4145    programming in ansi c
# Name: Title, dtype: object
# 4154    biochemical engineering
# Name: Title, dtype: object
# 4174    corporate social responsibility: managing and ...
# Name: Title, dtype: object
# 4191    A Textbook of Business and Industrial Laws
# Name: Title, dtype: object
# 4209    The periodic table at a glance
# Name: Title, dtype: object
# 4228    Software engineering
# Name: Title, dtype: object
# 4244    Computer Architecture
# Name: Title, dtype: object
# 4264    Satellite orbits: Models methods applications ...
# Name: Title, dtype: object
# 4273    Design of steel structures (With CD): CD8087-8096
# Name: Title, dtype: object
# 4293    Applied numerical methods with MATLAB for engi...
# Name: Title, dtype: object
# 4312    Research methodology: Methods and techniques
# Name: Title, dtype: object
# 4329    Elements of molecular spcetroscopy
# Name: Title, dtype: object
# 4349    Stereo chemistry: Conformation and mechanism
# Name: Title, dtype: object
# 4365    Computer applications in chemistry
# Name: Title, dtype: object
# 4382    Rod and Bar rolling: Theory and applications
# Name: Title, dtype: object
# 4398    Fundamentals of tribology
# Name: Title, dtype: object
# 4418    an introduction to the finite element method
# Name: Title, dtype: object
# 4435    Engineering materials properties ANDamp; selec...
# Name: Title, dtype: object
# 4449    The Finite Element Method : It's Basis and Fun...
# Name: Title, dtype: object
# 4465    A Practical English Grammar
# Name: Title, dtype: object
# 4484    Macroeconomics for Management Students
# Name: Title, dtype: object
# 4502    Logistics and Supply Chain Management Cases an...
# Name: Title, dtype: object
# 4522    Marketing Management
# Name: Title, dtype: object
# 4539    Numerical Linear Algebra:
# Name: Title, dtype: object
# 4558    Design of Experiments for Process Improvement ...
# Name: Title, dtype: object
# 4578    Plastics Engineering
# Name: Title, dtype: object
# 4597    Managerial Economics: Economic tools for today...
# Name: Title, dtype: object
# 4617    Thiruvilakin Oliyil Thamizhar Marumalarchi
# Name: Title, dtype: object
# 4630    Paripaadal
# Name: Title, dtype: object
# 4644    Thasildhar
# Name: Title, dtype: object
# 4663    Recent Advances in Bio-Technology
# Name: Title, dtype: object
# 4683    A Textbook of Organic Chemistry
# Name: Title, dtype: object
# 4703    Ezhundhiru Vizhithiru
# Name: Title, dtype: object
# 4722    Macro economics
# Name: Title, dtype: object
# 4742    What I Learned From Sam Walton : How To Compet...
# Name: Title, dtype: object
# 4762    Data mining: Concepts and techniques
# Name: Title, dtype: object
# 4781    Lateral marketing new techniques for finding b...
# Name: Title, dtype: object
# 4801    "Financial Management : Text, Problems and Cases"
# Name: Title, dtype: object
# 4821    Business analysis: visualizing business proces...
# Name: Title, dtype: object
# 4840    Finanacial Accounting
# Name: Title, dtype: object
# 4860    Legal Aspects of Business
# Name: Title, dtype: object
# 4879    Modern methods for robust
# Name: Title, dtype: object
# 4899    Game theory topics
# Name: Title, dtype: object
# 4919    Discriminant Analysis
# Name: Title, dtype: object
# 4939    Analysis of Nominal Data
# Name: Title, dtype: object
# 4959    Biosaline agriculture and high salinity tolerance
# Name: Title, dtype: object
# 4975    Managerial Economics : Theory and Practice
# Name: Title, dtype: object
# 4993    Comdex: Computer and financial accounting with...
# Name: Title, dtype: object
# 5006    Tholkappiyan Sollum Sinthanaigalum
# Name: Title, dtype: object
# 5022    Fundamentals of Human Resource Management
# Name: Title, dtype: object
# 5042    Matlab: An introduction with applications
# Name: Title, dtype: object
# 5062    optical Fiber Communications: Principles ANDam...
# Name: Title, dtype: object
# 5081    Trace analysis
# Name: Title, dtype: object
# 5098    Manufacturing technology
# Name: Title, dtype: object
# 5117    Tele Communication Engineering: Line Communica...
# Name: Title, dtype: object
# 5134    Food processing and preservation
# Name: Title, dtype: object
# 5151    Engineering Physics
# Name: Title, dtype: object
# 5169    Food Science
# Name: Title, dtype: object
# 5188    Basic concepts of analytical chemistry
# Name: Title, dtype: object
# 5204    Atomic and Molecular Spectroscopy
# Name: Title, dtype: object
# 5223    Comprehensive Biotechnology - 2
# Name: Title, dtype: object
# 5241    Environmental Chemistry
# Name: Title, dtype: object
# 5260    Data structures using C
# Name: Title, dtype: object
# 5278    Concepts in Biotechnology
# Name: Title, dtype: object
# 5293    Research methodology: Methods and techniques
# Name: Title, dtype: object
# 5310    Microprocessors and Microcomputer-Based System...
# Name: Title, dtype: object
# 5328    Thermodynamics and Thermal Engineering
# Name: Title, dtype: object
# 5347    core java: fundamentals
# Name: Title, dtype: object
# 5364    Measurement systems: Application and design
# Name: Title, dtype: object
# 5384    computer system architecture
# Name: Title, dtype: object
# 5402    Electronic communication systems
# Name: Title, dtype: object
# 5419    Signals and systems
# Name: Title, dtype: object
# 5432    Programming with ANSI and Turbo C
# Name: Title, dtype: object
# 5446    Organic Reaction Mechanisms
# Name: Title, dtype: object
# 5464    Engineering circuit analysis (With CD): CD8433...
# Name: Title, dtype: object
# 5482    Digital Fundamentals
# Name: Title, dtype: object
# 5498    GRE: Graduate record examination 2008: CD8474-...
# Name: Title, dtype: object
# 5514    Introduction to Chemical Engineering
# Name: Title, dtype: object
# 5533    Advanced Inorganic Chemistry
# Name: Title, dtype: object
# 5543    Business Law
# Name: Title, dtype: object
# 5556    Brand Management: The Indian Context
# Name: Title, dtype: object
# 5574    Mass - Transfer Operations
# Name: Title, dtype: object
# 5587    A textbook of engineering chemistry
# Name: Title, dtype: object
# 5601    Concise general knowledge manual 2009
# Name: Title, dtype: object
# 5621    Astrophysics stars and galaxies
# Name: Title, dtype: object
# 5640    Measure and Probability
# Name: Title, dtype: object
# 5660    Concepts in Biotechnology
# Name: Title, dtype: object
# 5679    Geographical Information System
# Name: Title, dtype: object
# 5699    Chemical Process Calculations: Lecture Notes
# Name: Title, dtype: object
# 5718    Principles of Electronic Communications Analog...
# Name: Title, dtype: object
# 5735    modern physics
# Name: Title, dtype: object
# 5751    Mathematics - III
# Name: Title, dtype: object
# 5764    Advanced C Programming
# Name: Title, dtype: object
# 5782    Introduction to finite elements in engineering...
# Name: Title, dtype: object
# 5801    An english chinese dictionary (Multifunctional)
# Name: Title, dtype: object
# 5820    The Historical Status of China's Tibet
# Name: Title, dtype: object
# 5836    Indian Financial Systems
# Name: Title, dtype: object
# 5855    History : A Journey Through the ages Themes in...
# Name: Title, dtype: object
# 5874    Successful glossary of common library terms
# Name: Title, dtype: object
# 5892    Optical fiber communications principles and pr...
# Name: Title, dtype: object
# 5911    Srimad Bhagavatam - Canto 8
# Name: Title, dtype: object
# 5930    Financial Accounting: Principles ANDamp; Pract...
# Name: Title, dtype: object
# 5948    Telecommunication Engineering : Line Communica...
# Name: Title, dtype: object
# 5967    Optoelectronics ANDamp; Fibre Options Communic...
# Name: Title, dtype: object
# 5980    Biotechnology from A to Z
# Name: Title, dtype: object
# 5999    Introduction to engineering materials
# Name: Title, dtype: object
# 6019    Textbook of gynaecology
# Name: Title, dtype: object
# 6038    Organic chemistry III
# Name: Title, dtype: object
# 6058    "Legumes in India Applications in Food, Medici...
# Name: Title, dtype: object
# 6078    Lockhart ANDamp; Wiseman's Crop Husbandry
# Name: Title, dtype: object
# 6098    Financial Economics
# Name: Title, dtype: object
# 6118    History of the Arabs
# Name: Title, dtype: object
# 6135    Circuit analysis
# Name: Title, dtype: object
# 6148    Power plant engineering
# Name: Title, dtype: object
# 6164    Comprehensive Design of Steel Structures
# Name: Title, dtype: object
# 6177    A First Course in Fluid Dynamics
# Name: Title, dtype: object
# 6194    Engineering Thermodynamics : Through Examples
# Name: Title, dtype: object
# 6211    thamizhar nattup padalgal
# Name: Title, dtype: object
# 6231    Thunba veenayum aanantha bairaviyum/ (Agony an...
# Name: Title, dtype: object
# 6250    Maanikam
# Name: Title, dtype: object
# 6270    Kalviyum kuzhanthaigalum
# Name: Title, dtype: object
# 6290    Puthir chinthanai kanitham
# Name: Title, dtype: object
# 6310    punidar annai terasa
# Name: Title, dtype: object
# 6329    mega thulli vizha
# Name: Title, dtype: object
# 6349    vinotha vadivangal
# Name: Title, dtype: object
# 6369    pathumaigal sonna paravasa kathaigal
# Name: Title, dtype: object
# 6389    nattumarunthukul eliya muraikal
# Name: Title, dtype: object
# 6409    Nugarvor paathukappu sattam.
# Name: Title, dtype: object
# 6428    Unkalaal mudiyum
# Name: Title, dtype: object
# 6448    Sanga illakiyam:pathupattu part-2
# Name: Title, dtype: object
# 6468    1666 podhu arivu vinaadi vinaa
# Name: Title, dtype: object
# 6482    a treatise on the mathematical theory of elast...
# Name: Title, dtype: object
# 6495    Introduction to research methodology in agricu...
# Name: Title, dtype: object
# 6515    MPLS and VPN - Architectures
# Name: Title, dtype: object
# 6533    Mechatronics source book
# Name: Title, dtype: object
# 6553    Physico chemical ground water remediation
# Name: Title, dtype: object
# 6573    Atmospheric Re-Entry Vehicle mechanics
# Name: Title, dtype: object
# 6593    Current at the nanoscale
# Name: Title, dtype: object
# 6613    The international business envirnoment
# Name: Title, dtype: object
# 6633    Observation and control for operator semi groups
# Name: Title, dtype: object
# 6653    Self assembly and nanotechnology : A force bal...
# Name: Title, dtype: object
# 6673    Strategies for Business Markets and Business C...
# Name: Title, dtype: object
# 6693    Industrial Relations
# Name: Title, dtype: object
# 6712    Principles marketing
# Name: Title, dtype: object
# 6732    Effective public relations and media strategy
# Name: Title, dtype: object
# 6752    Engineering ethics
# Name: Title, dtype: object
# 6768    Digital circuits and design
# Name: Title, dtype: object
# 6784    Biotechnology an introduction
# Name: Title, dtype: object
# 6800    Computer Architecture and organization : An in...
# Name: Title, dtype: object
# 6816    Design of machine elements
# Name: Title, dtype: object
# 6833    Environmental challeanges planning and develop...
# Name: Title, dtype: object
# 6852    Applied biotechnology
# Name: Title, dtype: object
# 6870    Circuit analysis
# Name: Title, dtype: object
# 6887    Verilog HDL: A guide to digital design and syn...
# Name: Title, dtype: object
# 6907    Compensation Management
# Name: Title, dtype: object
# 6926    Structural Synthesis is precision Elasticity
# Name: Title, dtype: object
# 6945    quantum mechanics
# Name: Title, dtype: object
# 6964    Strategic market management
# Name: Title, dtype: object
# 6981    General Studies manual 2009
# Name: Title, dtype: object
# 7001    DSP for in vehicle and mobile systems
# Name: Title, dtype: object
# 7021    "Bio organic,Bio inorganic and supra molecular...
# Name: Title, dtype: object
# 7037    Data Networks
# Name: Title, dtype: object
# 7056    Cooprative communications and Networking.
# Name: Title, dtype: object
# 7075    Mechanics of materials (With CD): CD8916
# Name: Title, dtype: object
# 7093    Carbohydrate chemistry
# Name: Title, dtype: object
# 7112    corrosion resistant linings and coatings
# Name: Title, dtype: object
# 7129    Environmental biotechnology
# Name: Title, dtype: object
# 7149    Essential of organic chemistry 1
# Name: Title, dtype: object
# 7166    Marketing Management
# Name: Title, dtype: object
# 7185    A course in abstract algebra.
# Name: Title, dtype: object
# 7204    Business Legislation for Management
# Name: Title, dtype: object
# 7222    Getting strted with matlab 7
# Name: Title, dtype: object
# 7240    Operation research.
# Name: Title, dtype: object
# 7259    Applied probability
# Name: Title, dtype: object
# 7279    molecular and atomic spectroscopy
# Name: Title, dtype: object
# 7299    oil field chemicals
# Name: Title, dtype: object
# 7317    "Microprocessors - Architecture,programming an...
# Name: Title, dtype: object
# 7332    Information security:Incident response and dis...
# Name: Title, dtype: object
# 7351    Operations research: Applications and algorith...
# Name: Title, dtype: object
# 7371    Firewalls and network security
# Name: Title, dtype: object
# 7390    Elements of Data Compression
# Name: Title, dtype: object
# 7408    Unit Operations and unit processes
# Name: Title, dtype: object
# 7426    mosfet theory and design
# Name: Title, dtype: object
# 7443    Semi conductor devices.
# Name: Title, dtype: object
# 7461    Marketing in a nutsell
# Name: Title, dtype: object
# 7476    Process control system and instrumentation
# Name: Title, dtype: object
# 7492    Entrepreneurship in the New Millennium
# Name: Title, dtype: object
# 7511    On socrates
# Name: Title, dtype: object
# 7530    Ganga
# Name: Title, dtype: object
# 7548    Discrete mathematics with graph theory
# Name: Title, dtype: object
# 7565    managing workplace negativity
# Name: Title, dtype: object
# 7583    HRD score card 2500 based on HRD audit
# Name: Title, dtype: object
# 7603    Data communications and networking
# Name: Title, dtype: object
# 7620    Beginning Finite Mathematics
# Name: Title, dtype: object
# 7640    "Couplings and joints : Design, selection and ...
# Name: Title, dtype: object
# 7660    Capital Structure and firm performance
# Name: Title, dtype: object
# 7680    Solving direct and inverse heat conduction pro...
# Name: Title, dtype: object
# 7700    Recent progress in medicinal plants : Phyto ch...
# Name: Title, dtype: object
# 7720    Image databases : search and retrieval of digi...
# Name: Title, dtype: object
# 7740    Advanced fixed income analysis
# Name: Title, dtype: object
# 7760    "Diesel engineering: Brakes, steering and susp...
# Name: Title, dtype: object
# 7780    Electronic Engine Control
# Name: Title, dtype: object
# 7799    Emotional intelligence at work : A professiona...
# Name: Title, dtype: object
# 7818    Queuing Theory and Telecommunications Networks...
# Name: Title, dtype: object
# 7837    Measure ANDamp; Probability
# Name: Title, dtype: object
# 7855    Introduction to operation research (With CD): ...
# Name: Title, dtype: object
# 7873    Microprocessors and interfacing
# Name: Title, dtype: object
# 7892    Human Resource Management
# Name: Title, dtype: object
# 7912    Computer architecture (With CD): CD9344-9353
# Name: Title, dtype: object
# 7932    an introduction to market ANDamp; social resea...
# Name: Title, dtype: object
# 7952    process control : theory and aplications
# Name: Title, dtype: object
# 7970    Circuit analysis: principles and applications.
# Name: Title, dtype: object
# 7990    Time Management.
# Name: Title, dtype: object
# 8010    make winning a habit
# Name: Title, dtype: object
# 8028    Negotiation.
# Name: Title, dtype: object
# 8047    Mathematical foundations of computer science
# Name: Title, dtype: object
# 8067    How write sales letter that sell: Learn to sec...
# Name: Title, dtype: object
# 8085    Operations Research
# Name: Title, dtype: object
# 8102    Discrete mathematics
# Name: Title, dtype: object
# 8119    Theory of machines
# Name: Title, dtype: object
# 8136    Digital computer fundamentals.
# Name: Title, dtype: object
# 8156    an introduction to analog ANDamp; digital comm...
# Name: Title, dtype: object
# 8172    Introduction to electro dynamics
# Name: Title, dtype: object
# 8188    Modeling indoor air pollution
# Name: Title, dtype: object
# 8202    Bio-Nano-Geo sciences:the future challenge
# Name: Title, dtype: object
# 8219    Principles of digital electronics
# Name: Title, dtype: object
# 8234    Probability and statisitcs
# Name: Title, dtype: object
# 8251    Basic electrical engineering
# Name: Title, dtype: object
# 8265    Computers as components : Principles of embedd...
# Name: Title, dtype: object
# 8284    Python: Creat -modify-reuse
# Name: Title, dtype: object
# 8303    Computer system architecture
# Name: Title, dtype: object
# 8315    Core servlets and java serve pages
# Name: Title, dtype: object
# 8332    Total quality management
# Name: Title, dtype: object
# 8352    Analysis of electric machinery and drive systems
# Name: Title, dtype: object
# 8371    Digital computer fundamentals
# Name: Title, dtype: object
# 8387    Modern statistics for the life sciences learn ...
# Name: Title, dtype: object
# 8397    Research methodology: Methods and techniques
# Name: Title, dtype: object
# 8410    If tomorrow comes
# Name: Title, dtype: object
# 8424    Textbook of applied mechanics
# Name: Title, dtype: object
# 8437    Textbook of Manufacturing technology
# Name: Title, dtype: object
# 8455    Optical fibers and fibre optic communication s...
# Name: Title, dtype: object
# 8472    Engineering physics II
# Name: Title, dtype: object
# 8491    Engineering physics
# Name: Title, dtype: object
# 8509    Delight of computer networks
# Name: Title, dtype: object
# 8526    Automobile engineering: Theory and practice
# Name: Title, dtype: object
# 8543    Engineering mechanics
# Name: Title, dtype: object
# 8563    Mathematical foundations of computer science
# Name: Title, dtype: object
# 8574    Biotechnology food fermentation microbiology b...
# Name: Title, dtype: object
# 8592    Environmental science and engineering
# Name: Title, dtype: object
# 8606    Power semiconductor drives
# Name: Title, dtype: object
# 8624    Design and analysis of Algorithms
# Name: Title, dtype: object
# 8638    Theory of elasticity
# Name: Title, dtype: object
# 8654    I.A.S. Kalanchiyam
# Name: Title, dtype: object
# 8674    Biotechnology
# Name: Title, dtype: object
# 8693    Research and writing across the disciplines
# Name: Title, dtype: object
# 8712    Cost accounting
# Name: Title, dtype: object
# 8731    Scaling fractals and Wavelets
# Name: Title, dtype: object
# 8749    Developmental Biology: A manual
# Name: Title, dtype: object
# 8767    Nuclear radiation detection measurements and a...
# Name: Title, dtype: object
# 8786    Advance trace analysis
# Name: Title, dtype: object
# 8804    Introduction to market social research
# Name: Title, dtype: object
# 8823    Evaluating public relations: A best practice g...
# Name: Title, dtype: object
# 8843    Know yourself: Achieve your goals through bett...
# Name: Title, dtype: object
# 8863    Profit brand
# Name: Title, dtype: object
# 8883    Ultimate job search
# Name: Title, dtype: object
# 8903    "A+, network+, security+: Exams in a nutshell"
# Name: Title, dtype: object
# 8921    Network security assessment
# Name: Title, dtype: object
# 8941    Web services essentials
# Name: Title, dtype: object
# 8946    Marker
# Name: Title, dtype: object
# 8962    Managing software requirement: A use case appr...
# Name: Title, dtype: object
# 8981    "Acquired immuno deficiency syndrome: Biologic...
# Name: Title, dtype: object
# 9001    Taxmann's companies act: With SEBI rules/regul...
# Name: Title, dtype: object
# 9021    Basic international taxation
# Name: Title, dtype: object
# 9040    Perl programming language
# Name: Title, dtype: object
# 9059    Aspect J in action
# Name: Title, dtype: object
# 9077    Pro/engineer wildfire 3.0 for engineers and de...
# Name: Title, dtype: object
# 9096    Fundamentals of geographic information systems
# Name: Title, dtype: object
# 9114    "Storage networks explained: Basics and applic...
# Name: Title, dtype: object
# 9133    Kuby Immunology
# Name: Title, dtype: object
# 9151    Financial management
# Name: Title, dtype: object
# 9171    Power metallurgy
# Name: Title, dtype: object
# 9189    Stereo chemistry conformation and mechanism
# Name: Title, dtype: object
# 9206    Six sigma project management
# Name: Title, dtype: object
# 9223    Food science
# Name: Title, dtype: object
# 9243    Solving engineering mechanics problems with MA...
# Name: Title, dtype: object
# 9263    Polymer composite
# Name: Title, dtype: object
# 9283    Unconventional manufacturing process
# Name: Title, dtype: object
# 9301    Foundations of behavioral statistics: An insig...
# Name: Title, dtype: object
# 9319    Top telemarketing techniques
# Name: Title, dtype: object
# 9338    Separation chemistry
# Name: Title, dtype: object
# 9355    Textbook of engineering mechanics
# Name: Title, dtype: object
# 9368    Engineering electromagnetic
# Name: Title, dtype: object
# 9382    Introduction to international marketing guide ...
# Name: Title, dtype: object
# 9400    Financial management
# Name: Title, dtype: object
# 9417    Fundamentals of orthopaedics
# Name: Title, dtype: object
# 9434    Textbook of biotechnology
# Name: Title, dtype: object
# 9452    Fundamentals of life insurance theories and ap...
# Name: Title, dtype: object
# 9470    Management accounting: Principles and practice
# Name: Title, dtype: object
# 9490    Human rights and sovereignty declaration and i...
# Name: Title, dtype: object
# 9510    Pandaiya Indiya: Panbadum Nagarigamum
# Name: Title, dtype: object
# 9524    Encyclopedia of nations
# Name: Title, dtype: object
# 9542    Kalvi sinthanaikal: Bharathiyar
# Name: Title, dtype: object
# 9558    Textbook of engineering drawing: First angle p...
# Name: Title, dtype: object
# 9574    "Profile of engineering education in india: St...
# Name: Title, dtype: object
# 9588    "Formulary of cosmetic preparations creams, lo...
# Name: Title, dtype: object
# 9606    Committed enterprise: How to make vision and v...
# Name: Title, dtype: object
# 9624    Invisible rays: The history of radio activity
# Name: Title, dtype: object
# 9644    Manufacturing processes for technology
# Name: Title, dtype: object
# 9663    Half moon investigations
# Name: Title, dtype: object
# 9683    Image analysis random fields and markov chain ...
# Name: Title, dtype: object
# 9701    Solid state electronic devices
# Name: Title, dtype: object
# 9719    Environmental science: Earth as a living planet
# Name: Title, dtype: object
# 9736    Advanced microprocessors and micro controllers
# Name: Title, dtype: object
# 9755    Principles of the solid state
# Name: Title, dtype: object
# 9775    "Operations research: Applications and algorit...
# Name: Title, dtype: object
# 9795    Coordination compounds
# Name: Title, dtype: object
# 9813    Finite element analysis and programming: An in...
# Name: Title, dtype: object
# 9830    Marketing management
# Name: Title, dtype: object
# 9850    Essentials of discrete mathematics
# Name: Title, dtype: object
# 9869    Electric machines
# Name: Title, dtype: object
# 9889    Advanced practical process control (with CD): ...
# Name: Title, dtype: object
# 9909    Pharmacology and pharmaco therapeutics
# Name: Title, dtype: object
# 9927    Discrete mathematical structures with applicat...
# Name: Title, dtype: object
# 9946    Elements of discrete mathematics:A computer or...
# Name: Title, dtype: object
# 9965    Discrete mathematics
# Name: Title, dtype: object
# 9985    Discrete mathematics
# Name: Title, dtype: object
# 10005    Discrete mathematics and its applications with...
# Name: Title, dtype: object
# 10021    Introduction to probability and statistics
# Name: Title, dtype: object
# 10040    Introduction to probability and statistics
# Name: Title, dtype: object
# 10054    Discrete mathematics
# Name: Title, dtype: object
# 10073    Probability and statistics with reliability qu...
# Name: Title, dtype: object
# 10093    Probability and statistics with reliability qu...
# Name: Title, dtype: object
# 10112    Discrete mathematical structures
# Name: Title, dtype: object
# 10132    Discrete mathematical structures
# Name: Title, dtype: object
# 10152    Miller and freunds probability and statistics ...
# Name: Title, dtype: object
# 10169    Graph theory: With applications to engineering...
# Name: Title, dtype: object
# 10187    "Operations research: An introduction: CD10075...
# Name: Title, dtype: object
# 10205    8051 microcontroller and embedded systems usin...
# Name: Title, dtype: object
# 10225    Electromagnetic with applications
# Name: Title, dtype: object
# 10243    Software engineering: A practitioner's approach
# Name: Title, dtype: object
# 10256    Software testing in the real world: Improving ...
# Name: Title, dtype: object
# 10275    Merchant banking
# Name: Title, dtype: object
# 10291    Medical pharmacology at a glance
# Name: Title, dtype: object
# 10308    Financial accounting
# Name: Title, dtype: object
# 10325    Manufacturing processes
# Name: Title, dtype: object
# 10341    Probability and statistics for engineers
# Name: Title, dtype: object
# 10359    Beautiful architecture: Leading thinkers revea...
# Name: Title, dtype: object
# 10374    Communication systems
# Name: Title, dtype: object
# 10393    PC architecture and peripherals
# Name: Title, dtype: object
# 10410    Basics of biotechnology
# Name: Title, dtype: object
# 10427    Power of oracle 10g
# Name: Title, dtype: object
# 10440    Textbook of theory of machines: In SI units
# Name: Title, dtype: object
# 10458    Classical electromagnetic theory
# Name: Title, dtype: object
# 10478    Software engineering
# Name: Title, dtype: object
# 10495    Microprocessors and interfacing: Programming a...
# Name: Title, dtype: object
# 10515    Introduction to solid state physics
# Name: Title, dtype: object
# 10533    Programming and customizing the 8051 microcont...
# Name: Title, dtype: object
# 10552    Data communications and computer networks
# Name: Title, dtype: object
# 10568    Digital electronics
# Name: Title, dtype: object
# 10585    Energy environment ecology and society
# Name: Title, dtype: object
# 10602    Digital principles and logic design (with CD):...
# Name: Title, dtype: object
# 10620    Network and system
# Name: Title, dtype: object
# 10635    Fundamentals of financial management
# Name: Title, dtype: object
# 10653    Operations research: An introduction (with CD)...
# Name: Title, dtype: object
# 10671    Software engineering: A practitioners approach
# Name: Title, dtype: object
# 10688    Fiber optic communications technology
# Name: Title, dtype: object
# 10706    Nano and micro electromechanical systems: Fund...
# Name: Title, dtype: object
# 10723    Optical fiber communications: Principles and p...
# Name: Title, dtype: object
# 10743    "Surface modification and mechanisms: Friction...
# Name: Title, dtype: object
# 10758    Engineering physics
# Name: Title, dtype: object
# 10770    Mathematical for engineers
# Name: Title, dtype: object
# 10790    Advanced engineering mathematics
# Name: Title, dtype: object
# 10808    Srimad bhagavatam
# Name: Title, dtype: object
# 10828    Srimad bhagavatam
# Name: Title, dtype: object
# 10847    Biotechnology: Principles and applications
# Name: Title, dtype: object
# 10866    Introduction to condensed matter physics
# Name: Title, dtype: object
# 10884    Physics of the atom
# Name: Title, dtype: object
# 10903    Mathematics and computational models
# Name: Title, dtype: object
# 10922    Models in geography
# Name: Title, dtype: object
# 10937    Understanding geographical map entries for civ...
# Name: Title, dtype: object
# 10955    Graphs: Theory and algorithms
# Name: Title, dtype: object
# 10974    Computer organization and architecture: Design...
# Name: Title, dtype: object
# 10994    Elasticity: Theory applications and numerics
# Name: Title, dtype: object
# 11013    The Art of Multiprocessor Programming
# Name: Title, dtype: object
# 11031    Vehicle handling dynamics: Theory and application
# Name: Title, dtype: object
# 11050    Engineering thermodynamics
# Name: Title, dtype: object
# 11069    Optoelectronics and fiber optic technology
# Name: Title, dtype: object
# 11088    Introduction to biotechnology and genetic engi...
# Name: Title, dtype: object
# 11106    Operations research
# Name: Title, dtype: object
# 11121    Spss or psychologists
# Name: Title, dtype: object
# 11137    3 Mistakes of my life
# Name: Title, dtype: object
# 11155    Probability and statistics for engineers
# Name: Title, dtype: object
# 11161    Devil and miss prym
# Name: Title, dtype: object
# 11175    Nehru and modern india: An anatomy of nation b...
# Name: Title, dtype: object
# 11193    Solid state engineering physics
# Name: Title, dtype: object
# 11213    Arunachal pradesh: Past and present
# Name: Title, dtype: object
# 11232    Automotive control systems: For engine driveli...
# Name: Title, dtype: object
# 11251    Scheduling: Theory algorithms and systems
# Name: Title, dtype: object
# 11270    Complete screenwriters manual: A comprehensive...
# Name: Title, dtype: object
# 11290    Complex variable
# Name: Title, dtype: object
# 11309    Institutional financing for small scale indust...
# Name: Title, dtype: object
# 11329    Biotechnology
# Name: Title, dtype: object
# 11349    Organic synthesis: Special techniques
# Name: Title, dtype: object
# 11369    Interfacing through microprocessor
# Name: Title, dtype: object
# 11387    Marketing: Planning implementation and control
# Name: Title, dtype: object
# 11406    Industrial organizational psychology
# Name: Title, dtype: object
# 11426    Security analysis and portfolio management
# Name: Title, dtype: object
# 11446    Advanced course on structural health assessmen...
# Name: Title, dtype: object
# 11466    Entrepreneurship
# Name: Title, dtype: object
# 11485    Textbook on principles and practice of life in...
# Name: Title, dtype: object
# 11503    Marketing management: Text and cases
# Name: Title, dtype: object
# 11523    Computer control of process
# Name: Title, dtype: object
# 11543    ANSI C programming
# Name: Title, dtype: object
# 11561    Advanced digital systems: Experiments and conc...
# Name: Title, dtype: object
# 11580    "Digital logic and microprocessors design with...
# Name: Title, dtype: object
# 11598    Advanced computer architecture: Parallelism sc...
# Name: Title, dtype: object
# 11612    Programming in basic
# Name: Title, dtype: object
# 11628    Parallel computer architecture: A hardware sof...
# Name: Title, dtype: object
# 11646    Manufacturing processes for engineering materials
# Name: Title, dtype: object
# 11662    Basic electrical engineering
# Name: Title, dtype: object
# 11680    Fiber optic communications
# Name: Title, dtype: object
# 11700    Analysis and design of machine element
# Name: Title, dtype: object
# 11719    "Bond graph in modeling, simulation and fault ...
# Name: Title, dtype: object
# 11736    Theory of plasticity
# Name: Title, dtype: object
# 11755    Essential MATLAB for engineers and scientists
# Name: Title, dtype: object
# 11773    Introduction to engineering materials
# Name: Title, dtype: object
# 11790    Engineering circuit analysis
# Name: Title, dtype: object
# 11810    Fundamentals of manufacturing processes
# ...
# Name: Title, dtype: object
# 14327    Solid state physics
# Name: Title, dtype: object
# 14345    MATLAB: Programming for engineers
# Name: Title, dtype: object
# 14363    Computer as components: Principles of embedded...
# Name: Title, dtype: object
# 14382    Principles of digital systems design: Using VH...
# Name: Title, dtype: object
# 14401    8051 microcontroller (with CD): CD12357-CD12359
# Name: Title, dtype: object
# 14417    Thinking in java for SE5/6
# Name: Title, dtype: object
# 14437    Ethics in engineering
# Name: Title, dtype: object
# 14455    Computer system architecture
# Name: Title, dtype: object
# 14473    Data communications and networking
# Name: Title, dtype: object
# 14490    C programming language
# Name: Title, dtype: object
# 14510    Introduction to computers
# Name: Title, dtype: object
# 14527    Let us C
# Name: Title, dtype: object
# 14545    Discrete mathematical structures
# Name: Title, dtype: object
# 14564    Numerical methods with programs in C
# Name: Title, dtype: object
# 14581    Engineering physics II
# Name: Title, dtype: object
# 14601    Engineering mathematics: For semester IANDamp;II
# Name: Title, dtype: object
# 14617    Engineering and general geology
# Name: Title, dtype: object
# 14632    Design of reinforced concrete structures (limi...
# Name: Title, dtype: object
# 14650    Process control instrumentation technology
# Name: Title, dtype: object
# 14668    Biotechnology
# Name: Title, dtype: object
# 14688    Elements of biotechnology
# Name: Title, dtype: object
# 14707    Inorganic chemistry
# Name: Title, dtype: object
# 14727    Global marketing
# Name: Title, dtype: object
# 14746    Financial management: Theory and practice: CD1...
# Name: Title, dtype: object
# 14766    Management information systems
# Name: Title, dtype: object
# 14785    General and commercial law
# Name: Title, dtype: object
# 14803    Dynamics of entrepreneurial development and ma...
# Name: Title, dtype: object
# 14822    Managerial economics
# Name: Title, dtype: object
# 14841    Operations management for competitive advantag...
# Name: Title, dtype: object
# 14857    Inheritance
# Name: Title, dtype: object
# 14872    Tiger by the tail
# Name: Title, dtype: object
# 14884    Titanic
# Name: Title, dtype: object
# 14897    Jack reacher thrill
# Name: Title, dtype: object
# 14900    Calico Joe
# Name: Title, dtype: object
# 14905    Other side of midnight
# Name: Title, dtype: object
# 14910    Best laid plans
# Name: Title, dtype: object
# 14921    Indian 2020: A vision for the new millennium
# Name: Title, dtype: object
# 14940    Inspiring thoughts
# Name: Title, dtype: object
# 14954    Veronika decides to die
# Name: Title, dtype: object
# 14966    Winner stands alone
# Name: Title, dtype: object
# 14980    Rusty runs away
# Name: Title, dtype: object
# 14990    Leadership wisdom from the monk who sold his f...
# Name: Title, dtype: object
# 15002    Triangle of terror
# Name: Title, dtype: object
# 15015    Sachin born to bat
# Name: Title, dtype: object
# 15032    India and the global financial crisis
# Name: Title, dtype: object
# 15043    3 mistakes of my life
# Name: Title, dtype: object
# 15055    Treasure
# Name: Title, dtype: object
# 15063    Harry potter and the chamber of secrets
# Name: Title, dtype: object
# 15078    Roadside crosses
# Name: Title, dtype: object
# 15089    Saving faith
# Name: Title, dtype: object
# 15102    "Great works of alexandre dumas: The tree musk...
# Name: Title, dtype: object
# 15116    On wings of eagles
# Name: Title, dtype: object
# 15124    Heroes of olympus: The lost hero
# Name: Title, dtype: object
# 15131    Dracula
# Name: Title, dtype: object
# 15146    Intelligent investor
# Name: Title, dtype: object
# 15164    Signals and systems
# Name: Title, dtype: object
# 15182    Communication systems
# Name: Title, dtype: object
# 15198    Plasmon resonances in nanoparticles
# Name: Title, dtype: object
# 15217    Engineering thermodynamics
# Name: Title, dtype: object
# 15234    Patriot games
# Name: Title, dtype: object
# 15253    Continum mechanics
# Name: Title, dtype: object
# 15273    Extra solar planets
# Name: Title, dtype: object
# 15291    Engineering circuit analysis
# Name: Title, dtype: object
# 15310    Linear and nonlinear control of small-scale un...
# Name: Title, dtype: object
# 15329    Business statistics
# Name: Title, dtype: object
# 15346    Plant biotechnology: The genetic maniputation ...
# Name: Title, dtype: object
# 15366    Software testing: Principles and practices (wi...
# Name: Title, dtype: object
# 15384    Environmental science and engineering
# Name: Title, dtype: object
# 15394    Perspective on current affairs
# Name: Title, dtype: object
# 15402    MATLAB: An introduction with applications
# Name: Title, dtype: object
# 15422    A guide to matlab: For begineers and experienc...
# Name: Title, dtype: object
# 15440    Computer organization and architecture
# Name: Title, dtype: object
# 15459    Digital principles and applications
# Name: Title, dtype: object
# 15476    Engineering circuit analysis
# Name: Title, dtype: object
# 15494    Let us C
# Name: Title, dtype: object
# 15513    Operations research: An introduction
# Name: Title, dtype: object
# 15533    Software testing: Principles and practices
# Name: Title, dtype: object
# 15553    Engineering electromagnetics (with CD): CD1224...
# Name: Title, dtype: object
# 15572    Textbook of fluid mechanics and hydraulic mach...
# Name: Title, dtype: object
# 15587    Basic structural analysis
# Name: Title, dtype: object
# 15606    Design of foundation systems: Principles and p...
# Name: Title, dtype: object
# 15623    Dynamics of structures
# Name: Title, dtype: object
# 15641    Fundamentals of fluid mechanics
# Name: Title, dtype: object
# 15658    Principles of geographical information systems
# Name: Title, dtype: object
# 15677    Risk analysis foundations: Models and methods
# Name: Title, dtype: object
# 15695    Thermal engineering
# Name: Title, dtype: object
# 15711    Callisters materials science and engineering (...
# Name: Title, dtype: object
# 15731    Design of analog cmos integrated circuits
# Name: Title, dtype: object
# 15749    Signal and systems
# Name: Title, dtype: object
# 15767    Computers as components: Principles of embedde...
# Name: Title, dtype: object
# 15785    Process systems analysis and control
# Name: Title, dtype: object
# 15803    Analysis of structures: Theory design and deta...
# Name: Title, dtype: object
# 15821    Mechatronics
# Name: Title, dtype: object
# 15841    Marketing B2B
# Name: Title, dtype: object
# 15861    Operations research an introduction
# Name: Title, dtype: object
# 15880    Error correction coding: Mathematical methods ...
# Name: Title, dtype: object
# 15898    Swami vivekanandar avargalin vetri chithirangal
# Name: Title, dtype: object
# 15918    Last of the mohicans
# Name: Title, dtype: object
# 15937    Konku Tamizhaga Varalaru
# Name: Title, dtype: object
# 15956    Digital elevation models comparative study for...
# Name: Title, dtype: object
# 15976    Service marketing: Integrating cutomer focus a...
# Name: Title, dtype: object
# 15996    Advanced structures for architecture
# Name: Title, dtype: object
# 16016    Indian Architecture Buddhist And Hindu
# Name: Title, dtype: object
# 16036    Manitha uravil punitha dhaivam Thiruvaurt prak...
# Name: Title, dtype: object
# 16055    Architectural Drafting and Design with cd
# Name: Title, dtype: object
# 16073    Computational fluid dynamics: The basics with ...
# Name: Title, dtype: object
# 16091    GATE Tutor 2015 : Mechanical Engineering (With...
# Name: Title, dtype: object
# 16110    Architecture of Manasara
# Name: Title, dtype: object
# 16130    Offices:  Construction and design Manual
# Name: Title, dtype: object
# 16150    Fame and Architecture
# Name: Title, dtype: object
# 16170    KPF: American projects
# Name: Title, dtype: object
# 16190    Retail Rescue: Visions+ Strategies for reposit...
# Name: Title, dtype: object
# 16210    Complete illustrated Guide to Islamic Art and ...
# Name: Title, dtype: object
# 16230    Traditional Buildings of India
# Name: Title, dtype: object
# 16250    Identity Workspace
# Name: Title, dtype: object
# 16270    museum Display design
# Name: Title, dtype: object
# 16289    "Building Structures illustrated: Pattern, Sys...
# Name: Title, dtype: object
# 16304    automotive mechanics
# Name: Title, dtype: object
# 16321    Anuwad ki Vyavharik Samasyaen
# Name: Title, dtype: object
# 16339    215933 Total quality management
# Name: Title, dtype: object
# 16359    Bioinorganic chemistry
# Name: Title, dtype: object
# 16379    Alcohol production through effective bioconver...
# Name: Title, dtype: object
# 16399    Calculation of biologically effective dose for...
# Name: Title, dtype: object
# 16419    Segmenting and profiling wellness  clients bas...
# Name: Title, dtype: object
# 16439    Production and properties of extracellular pro...
# Name: Title, dtype: object
# 16459    Studies on mobile agent based trust management...
# Name: Title, dtype: object
# 16479    High temperature resistivity and thermoelectri...
# Name: Title, dtype: object
# 16499    Solutions to the economic dispatch problems by...
# Name: Title, dtype: object
# 16519    In silico analysis of drug resistance of HIV-1...
# Name: Title, dtype: object
# 16539    Process development for synthesis of silver na...
# Name: Title, dtype: object
# 16559    Growth and characterization of organic and sem...
# Name: Title, dtype: object
# 16579    Insights in to the folding and binding of Homo...
# Name: Title, dtype: object
# 16599    Production and characterization of monoclonal ...
# Name: Title, dtype: object
# 16619    Clinical trial on drugs and cosmetics: Challen...
# Name: Title, dtype: object
# 16639    Antioxidant and cytotoxic activity of selected...
# Name: Title, dtype: object
# 16659    A solution to unit commitment problem using cl...
# Name: Title, dtype: object
# 16679    A study on factors influencing referral market...
# Name: Title, dtype: object
# 16699    Acyclic edge colouring in certain interconnect...
# Name: Title, dtype: object
# 16719    STUDIES ON SUBCLASSES OF ANALYTIC FUNCTIONS AS...
# Name: Title, dtype: object
# 16739    FEEDBACK QUEUEING MODELS WITH OPTIONAL VACATIO...
# Name: Title, dtype: object
# 16759    Induction of terminal differentiation with sel...
# Name: Title, dtype: object
# 16779    Studies of deleterious mutations on OCA I-IV g...
# Name: Title, dtype: object
# 16799    Development and analysis of effective conducte...
# Name: Title, dtype: object
# 16819    Efficacy of fly ash stabilised expansive clay ...
# Name: Title, dtype: object
# 16839    ANTIDIABETIC AND ANTIBACTERIAL ACTIVITY OF NEE...
# Name: Title, dtype: object
# 16859    HYPOGLYCEMIC AND INSULIN SENSITIZING EFFECT OF...
# Name: Title, dtype: object
# 16879    LUNG VOLUME RECONSTRUCTION FROM BIPLANAR RADIO...
# Name: Title, dtype: object
# 16899    IDENTIFICATION AND CHARACTERIZATION OF POTENTI...
# Name: Title, dtype: object
# 16919    FUZZY DECISION TREES AND ITS IMPROVEMENTS USIN...
# Name: Title, dtype: object
# 16939    A PREVENTION MODEL FOR WEB APPLICATION SESSION...
# Name: Title, dtype: object
# 16959    "STRENGTH, FRACTURE TOUGHNESS AND FATIGUE CRAC...
# Name: Title, dtype: object
# 16979    INVESTOR�S TRADING BEHAVIOUR: AN ANALYSIS ON B...
# Name: Title, dtype: object
# 16999    EFFECT OF POND ASH AND STEEL FIBRE ON ENGINEER...
# Name: Title, dtype: object
# 17019    HYDRAZIDE BASED HYPERCOORDINATED SILICON(IV) C...
# Name: Title, dtype: object
# 17039    COMPUTATIONAL MODELS FOR METABOLIC DISORDERS
# Name: Title, dtype: object
# 17059    "CHENODEOXYCHOLIC ACID, AN ENDOGENOUS FXR LIGA...
# Name: Title, dtype: object
# 17079    PERFORMANCE ANALYSIS OF CHANNEL ALLOCATION MET...
# Name: Title, dtype: object
# 17099    DEMAND RESPONSE MODELLING IN SMART GRID USING ...
# Name: Title, dtype: object
# 17119    DYNAMIC CHARACTERIZATION AND INSTABILITY ANALY...
# Name: Title, dtype: object
# 17139    DEVELOPMENT AND CHARACTERIZATION OF BRUCELLA A...
# Name: Title, dtype: object
# 17159    DESIGN AND SIMULATION OF 1D PHOTONIC CRYSTALS ...
# Name: Title, dtype: object
# 17179    "'INVESTIGATION ON SYNTHESIS, STRUCTURAL, MAGN...
# Name: Title, dtype: object
# 17199    JEFFREY FLUID FLOW OVER A STRETCHING SHEET WIT...
# Name: Title, dtype: object
# 17219    FAECAL CARRIAGE OF ESBL PRODUCING BACTERIA AND...
# Name: Title, dtype: object
# 17239    'IN SILICO SCREENING AND LEAD IDENTIFICATION F...
# Name: Title, dtype: object
# 17259    ON SOME ASPECTS OF GRANULAR COMPUTING AND ROUG...
# Name: Title, dtype: object
# 17279    'AGENT BASED DETECTION MECHANISM TO OUTWIT DIS...
# Name: Title, dtype: object
# 17299    INVESTIGATIONS ON COLD METAL TRANSFER (CMT) WE...
# Name: Title, dtype: object
# 17319    PROTOTYPE FILTER DESIGN TECHNIQUES FOR FILTER ...
# Name: Title, dtype: object
# 17339    DYNAMIC SECURE GROUP KEY AGREEMENT MECHANISM F...
# Name: Title, dtype: object
# 17359    PROCESSING AND CHARACTERIZATION OF SiC /Al2O3 ...
# Name: Title, dtype: object
# 17379    "COMMITMENT, IDENTIFICATION, RESONANT LEADERSH...
# Name: Title, dtype: object
# 17399    Reconstructing the republic
# Name: Title, dtype: object
# 17419    Widows are not for burning
# Name: Title, dtype: object
# 17439    Chief justice: A candidate
# Name: Title, dtype: object
# 17459    Face and fiction
# Name: Title, dtype: object
# 17479    Indian economy
# Name: Title, dtype: object
# 17499    Constitutional and administrative law
# Name: Title, dtype: object
# 17519    Principles power and politics
# Name: Title, dtype: object
# 17539    Shorter constitution of india
# Name: Title, dtype: object
# 17559    India's constitution and politics
# Name: Title, dtype: object
# 17579    Words of wisdom: The best advice you are ever ...
# Name: Title, dtype: object
# 17599    Reviewing the constitution
# Name: Title, dtype: object
# 17619    Great african american lawyers
# Name: Title, dtype: object
# 17639    Economic survey 1998-99
# Name: Title, dtype: object
# 17659    Indian administration
# Name: Title, dtype: object
# 17679    Mass communication: The press
# Name: Title, dtype: object
# 17699    History magazine for young people cobblestone
# Name: Title, dtype: object
# 17719    Wisdom of the buddha: New horizons
# Name: Title, dtype: object
# 17739    Upanishads breath of the eternal
# Name: Title, dtype: object
# 17759    When bombay burned
# Name: Title, dtype: object
# 17779    Economic survey 2005-2006
# Name: Title, dtype: object
# 17799    Position regarding human rights issues
# Name: Title, dtype: object
# 17819    Economic survey 1992-93
# Name: Title, dtype: object
# 17839    Gospel of buddha
# Name: Title, dtype: object
# 17859    Classical philosophy
# Name: Title, dtype: object
# 17879    Social inequality
# Name: Title, dtype: object
# 17899    Sri basaveshwara: Eight centenary commemoratio...
# Name: Title, dtype: object
# 17919    Islamic doctrine and way of life
# Name: Title, dtype: object
# 17939    Doctrine of the buddha
# Name: Title, dtype: object
# 17959    Great mathematicians
# Name: Title, dtype: object
# 17979    Report on small scale sector
# Name: Title, dtype: object
# 17999    Inside a soviet embassy
# Name: Title, dtype: object
# 18019    Indian banking: Nature performance and problems
# Name: Title, dtype: object
# 18039    Consumer protection and weights and measures
# Name: Title, dtype: object
# 18059    End of poverty
# Name: Title, dtype: object
# 18079    Eight years progress of health and family welf...
# Name: Title, dtype: object
# 18099    Major constituions government and politics in ...
# Name: Title, dtype: object
# 18119    Social justice and the constitution
# Name: Title, dtype: object
# 18139    Constitution and the constituent assembly
# Name: Title, dtype: object
# 18159    Blueprint for freedom doukakis's
# Name: Title, dtype: object
# 18179    World: A general regional geography
# Name: Title, dtype: object
# 18199    Wealth capital money and credit
# Name: Title, dtype: object
# 18219    Indian parliamentry group: Annual report
# Name: Title, dtype: object
# 18239    Post american world
# Name: Title, dtype: object
# 18259    Law relating to electeral disqualification: Fr...
# Name: Title, dtype: object
# 18279    Proceedings of the national symposium on re-or...
# Name: Title, dtype: object
# 18299    Congressional procedures and the policy process
# Name: Title, dtype: object
# 18319    Over coming world hunger
# Name: Title, dtype: object
# 18339    Problems and practices of development banks
# Name: Title, dtype: object
# 18359    Power unto itself
# Name: Title, dtype: object

# %%
final_df.to_csv('koha.csv')
